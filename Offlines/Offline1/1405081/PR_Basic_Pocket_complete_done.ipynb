# %%
import numpy as np
import pandas as pd
import sklearn
from collections import Counter
import collections
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
class Perceptron:
    def __init__(self, learning_rate=0.1, iteration=100):
        self.lr = learning_rate
        self.iteration = iteration
        self.activation_func = self._unit_step_func
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        number_of_samples, number_of_features = X.shape

        # init parameters
        self.weights = np.zeros(number_of_features)
        self.bias = 0
        y_ = np.array(y)
        #print("Actual y ",y_)

        for _ in range(self.iteration):

            for idx, x_i in enumerate(X):
                #print(x_i)
                #print(self.weights)
                linear_output = np.dot(x_i, self.weights) + self.bias
                y_predicted = self.activation_func(linear_output)
                #print("In Loop ",y_predicted)
                # Perceptron update rule
                update = self.lr * (y_[idx] - y_predicted)
                self.weights += update * x_i
                self.bias += update
                #print(linear_output)
                
            

    def predict(self, X):
        linear_output = np.dot(X, self.weights) + self.bias
        y_predicted = self.activation_func(linear_output)
        #print("Predicted Value Count of Y ",collections.Counter(y_predicted))
        #print(y_predicted)
        return y_predicted

    def _unit_step_func(self, x):
        # print(x)
        return np.where(x <2,1,2) ####great 40 thik krse....
    def Pocket(self,X_train,y_train,X_test,y_test,learningRate):
        number_of_samples, number_of_features = X_train.shape
        self.weights=np.zeros(number_of_features)
        self.weights = np.reshape(self.weights, (-1, 1))
        misClassifications = 1
        classification=1
        minMisclassifications = 1000
        iteration = 0
        while (misClassifications != 0 and classification!=0 and (iteration<100)):
            iteration += 1
            misClassifications = 0
            classification=0
            for i in range(0, len(X_train)):
                currentX_train = X_train[i].reshape(-1, X_train.shape[1])
                currentX_test = X_test[i].reshape(-1, X_test.shape[1])
                currentY_train = y_train[i]
                currentY_test = y_test[i]
                wTx = np.dot(currentX_train, self.weights)[0][0]
                
                if currentY_train == 2 and wTx <= 0:
                    misClassifications += 1
                    #self.weights = self.weights + learningRate * np.transpose(currentX_train)
                    self.weights = self.weights + learningRate * np.transpose(currentX_train)
                elif currentY_train == 1 and wTx > 0:
                    misClassifications += 1
                    #self.weights = self.weights - learningRate * np.transpose(currentX_train)
                    self.weights = self.weights - learningRate * np.transpose(currentX_train)

    
            if misClassifications<minMisclassifications:
                minMisclassifications = misClassifications
                self.updated_weight=self.weights
        #print ("Minimum Misclassifications : ",minMisclassifications)
        #print('Updates weight is: ',self.weights)
        #print ("Best Case Accuracy of Pocket Learning Algorithm is: ",(((X_train.shape[0]-minMisclassifications)/X_train.shape[0])*100),"%")
        output=np.dot(X_test,self.updated_weight)
        y_predicted = self.activation_func(output)
        y_predicted = y_predicted.reshape([1, X_train.shape[0]])
        return y_predicted
if __name__ == "__main__":
    # Imports
    import matplotlib.pyplot as plt
    from sklearn.model_selection import train_test_split
    from collections import Counter
    import collections
    
    def fileReadSeparable():
        feature=list()
        label=list()
        flag=0
        f=open("trainLinearlySeparable.txt")
        for line in f:
            info=list()
            x=line.split()
            if(flag==0):
                for item in x:
                    item=float(item)
                    info.append(item)
                flag=1
            elif(flag==1):
                for i in range(0,len(x)-1):
                    item=float(x[i])
                    info.append(item)
                feature.append(info)
                label.append(float(x[len(x)-1]))
        X=np.array(feature)
        y=np.array(label)
        f.close()
        feature=list()
        label=list()
        flag=0
        f=open("testLinearlySeparable.txt")
        for line in f:
            info=list()
            x=line.split()
            for i in range(0,len(x)-1):
                item=float(x[i])
                info.append(item)
            feature.append(info)
            label.append(float(x[len(x)-1]))
        X_test=np.array(feature)
        y_test=np.array(label)
        f.close()
        X_train, X_test, y_train, y_test =(X,X_test,y,y_test)
        #print(X_train)
        return X_train,y_train,X_test,y_test
    
    def accuracy(y_true, y_pred):
        accuracy = np.sum(y_true == y_pred) / len(y_true)
        return accuracy
    def fileReadNonSeparable():
        feature=list()
        label=list()
        flag=0
        f=open("trainLinearlyNonSeparable.txt")
        for line in f:
            info=list()
            x=line.split()
            if(flag==0):
                for item in x:
                    item=float(item)
                    info.append(item)
                flag=1
            elif(flag==1):
                for i in range(0,len(x)-1):
                    item=float(x[i])
                    info.append(item)
                feature.append(info)
                label.append(float(x[len(x)-1]))
        X=np.array(feature)
        y=np.array(label)
        f.close()
        feature=list()
        label=list()
        flag=0
        f=open("testLinearlyNonSeparable.txt")
        for line in f:
            info=list()
            x=line.split()
            for i in range(0,len(x)-1):
                item=float(x[i])
                info.append(item)
            feature.append(info)
            label.append(float(x[len(x)-1]))
        X_test=np.array(feature)
        y_test=np.array(label)
        f.close()
        X_train, X_test, y_train, y_test =(X,X_test,y,y_test)
        #print(X_train)
        return X_train,y_train,X_test,y_test
    
    X_train,y_train,X_test,y_test=fileReadSeparable()
    X_train_non,y_train_non,X_test_non,y_test_non=fileReadNonSeparable()
    p = Perceptron(learning_rate=0.1, iteration=1000)
    p.fit(X_train, y_train)
    predictions = p.predict(X_test)
    for i in range(0,len(X_train)):
        currentX = X_train[i].reshape(-1, X_train.shape[1])
        currentY=y_train[i]
    print('Basic Perceptron Accuracy: %.3f' % accuracy_score(y_test,predictions))
    p=Perceptron()
    predictions=p.Pocket(X_train_non,y_train_non,X_test_non,y_test_non,.01)
    print("Pocket Perceptron classification accuracy", accuracy(y_test_non, predictions))
    predictions=p.Pocket(X_train_non,y_train_non,X_test_non,y_test_non,.01)
    predictions=predictions.reshape(1,X_test.shape[0])
    predictions=predictions.ravel()
    print("Pocket Perceptron classification accuracy ",accuracy_score(y_test_non,predictions))
# Out:
# Basic Perceptron Accuracy: 0.995
# Pocket Perceptron classification accuracy 0.9775
# Pocket Perceptron classification accuracy  0.9775
